# %%
# %sql
-- i am going to explore a route table 
-- use catalog boabricks;
-- use schema muthiah;
--select * from routes;
select * from boabricks.muthiah.routes

# %%
# %sql
-- delete some records
delete from muthiah.routes where route_id = 'R001'

# %%
# %sql describe detail muthiah.routes;
