# %%
# %sql
--Exploring route table
select * from boabricks.pradeep.routes

# %%
# %sql
--delete some records
delete from boabricks.pradeep.routes where route_id = 'R001'

# %%
# %sql
describe detail boabricks.pradeep.routes

# %%
# %sql
describe history boabricks.pradeep.routes

# %%
# %sql
restore table boabricks.pradeep.routes to version as of 1
