-- %%
%sql
--select * from boabricks.ganesan.routes;

use catalog boabricks;
use schema ganesan;
select * from routes;

-- %%
select * from boabricks.ganesan.emp;

-- %%
select * from boabricks.ganesan.emp where id = 1
