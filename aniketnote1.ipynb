-- %%
/Volumes/boabricks/aniket/anivol%sql/Volumes/boabricks/aniket/anivol
-- i am going to explore route table
use catalog boabricks;
use schema aniket;
select * from routes;

-- %%
%sql
-- going to remove few records from routes

delete from routes where route_id = 'R001'

-- %%
%sql
describe history routes

-- %%
%sql
restore table routes to version as of 0
